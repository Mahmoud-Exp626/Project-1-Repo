# %%
import requests
import json

# Import the API key
from config import geoapify_key

# Target country
target_country = "Jordan"

# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?country={target_country}&format=json&apiKey={geoapify_key}"

# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()



# Extract latitude and longitude
lat = geo_data["results"][0]["lat"]
lon = geo_data["results"][0]["lon"]


import hvplot.pandas
import pandas as pd

data = {
    'Longitude': [lon],
    'Latitude': [lat]
}

df = pd.DataFrame(data)


country_map = df.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    scale = 50,
    xlim=(-180, 180),  # Adjust x-axis range for longitude
    ylim=(-80, 80)     # Adjust y-axis range for latitude
)

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))

# Print the latitude and longitude
print('''
    Country: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_country, lat, lon))
# Out:
# {
#     "query": {
#         "country": "Jordan",
#         "parsed": {
#             "country": "Jordan",
#             "expected_type": "unknown"
#         },
#         "text": ""
#     },
#     "results": [
#         {
#             "address_line1": "Jordan",
#             "address_line2": "",
#             "bbox": {
#                 "lat1": 29.183401,
#                 "lat2": 33.3734848,
#                 "lon1": 34.8844372,
#                 "lon2": 39.2998604
#             },
#             "category": "administrative",
#             "country": "Jordan",
#             "country_code": "jo",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Jordan",
#             "lat": 31.1667049,
#             "lon": 36.941628,
# ...

# %%
country_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]
